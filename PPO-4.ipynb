# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[120, 246,  73],
#        [ 85,  99, 102],
#        [ 52,  42, 100]])

# %%
class ChargeEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Observation box
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start SOC
        self.state = 20 + random.randint(-3,3)
        # Set max SOC
        self.max_state = 100
        # Set power
        self.power = 20
        # Set price data
        self.priceArray = np.float32(np.array([36.22, 27.98, 4.6, 9.38, -0.43, 2.26, 4.02, 8.48, 18.73,
                                               20.64, 22.99, 18.93, 16.67, 9.51, 3.59, 2.31, 2.78, 6.3, 14.18,
                                               16.11, 21.42, 25.87, 30.71, 18.44]))
        # Set current index
        self.currentIndex = 0
        self.currentprice = 0
        # Set temp 
        self.temp = 0
        self.change = 0
        self.rate = 0
        self.profit = 0
        self.per = 0
        # Set median
        self.mid = np.median(self.priceArray)
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 sell 
        # 1 -1 = 0 hold
        # 2 -1 = 1 buy 
        
        self.currentprice = self.priceArray[self.currentIndex]
        
        # If state exceeds boundaries after the action due to power limit, set state to 100 or 0
        # change action based on new state
        if self.state == 0:
            if self.currentprice < self.mid - 2:
                action = 2
            else:
                action = 1
                
        # Hold when state >= 90 while approaching the end
        if self.state >= 80 and (len(self.priceArray) - 1) - self.currentIndex < 5:
            if self.profit - self.currentprice >= 0:
                action = 2
            else:
                action = 1
        # Buy when state < 100 while approaching the end
        elif (self.max_state - self.state) / self.power >= (len(self.priceArray) - 10) - self.currentIndex:
            if self.currentprice < self.mid - 2:
                action = 2
            else:
                action = 1
                
        if self.state == 100:
            if self.profit - self.currentprice >= 0 and (len(self.priceArray) - 1) - self.currentIndex > 5:
                action = 1
            else:
                action = 0
            

        # Calculate reward    
        # BUy
        # Give - reward

        
        if 0 <= self.state < 20:
            
            if action == 2:
                if self.currentprice < self.mid - 2:
                    reward = self.currentprice * 10 
                else:
                    reward = self.currentprice * 0.1
            elif action == 0:
                reward = -self.currentprice * 10
            else:
                if self.currentprice < self.mid - 2:
                    reward = -self.currentprice * 0.5
                else:
                    reward = 0                
            self.temp = - self.currentprice * (action - 1) * self.rate
        
        elif 20 <= self.state <= 80:
            if self.currentprice < self.mid - 2:
                reward = self.currentprice * (action - 1) + self.profit 
            elif self.currentprice > self.mid + 2:
                reward = -self.currentprice * (action - 1) + self.profit 
            else:
                reward = abs(abs(action) - 1) * self.mid
            self.temp = - self.currentprice * (action - 1) * self.rate
            
        else:
            if action == 0:
                if self.currentprice > self.mid + 2 and (len(self.priceArray) - 1) - self.currentIndex > 5:
                    reward = self.currentprice * 10 #* (self.state / self.max_state)
                else:
                    reward = self.currentprice * 0.1
                    
            elif action == 1:
                if (len(self.priceArray) - 1) - self.currentIndex > 5:
                    if self.currentprice > self.mid + 2:
                        reward = -self.currentprice * 0.1
                    else:
                        reward = 0
                else:
                    reward = 10
                    
            else:
                reward = -self.currentprice * 10
                
            self.temp = - self.currentprice * (action - 1) * self.rate
            
            
        
        self.profit += self.temp
        
        self.state += (action - 1) * self.power
        
        if (0 - self.power) < self.state < 0:
            self.state = 0
            self.rate = (0 - self.state) / self.power
        elif 100 < self.state < (self.max_state + self.power):
            self.state = 100
            self.rate = (self.state - self.max_state) / self.power
        else: 
            self.rate = 1
            
        # Move to the next price
        self.currentIndex += 1
        
        # Set Low boundary and Up boundary
        #Set end state
        if self.currentIndex == len(self.priceArray)-1: 
            done = True
            if self.state < 80:
                reward = -10000
            if self.profit < 0:
                reward = -1000
            if self.state >= 80 and self.profit >= 0:
                reward = 1000
        elif self.state < -0 or self.state > 100:
                done = True
                reward = -1000
        elif self.profit >=0 and self.state >= 90:
            done = True
            reward = 2000
        else:
            done = False       

        

        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info ,self.profit

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([20 + random.randint(-3,3)])#.astype(float)
        # Set max SOC
        self.max_state = 100
        # Set power
        self.power = 20
        # Set price data
        self.priceArray = np.float32(np.array([36.22, 27.98, 4.6, 9.38, -0.43, 2.26, 4.02, 8.48, 18.73,
                                               20.64, 22.99, 18.93, 16.67, 9.51, 3.59, 2.31, 2.78, 6.3, 14.18,
                                               16.11, 21.42, 25.87, 30.71, 18.44]))
        # Set current index
        self.currentIndex = 0
        self.currentprice = 0
        # Set temp 
        self.temp = 0
        self.change = 0
        self.rate = 0
        self.profit = 0
        # Set median
        self.mid = np.median(self.priceArray)
        return self.state

# %%
env=ChargeEnv()

# %%
env.observation_space.sample()
# Out:
# array([57.180286], dtype=float32)

# %%
env.reset()
# Out:
# array([17])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12372\1913415460.py in <module>
# ----> 1 check_env(env, warn=True)
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\env_checker.py in check_env(env, warn, skip_render_check)
#     286
#     287     # ============ Check the returned values ===============
# --> 288     _check_returned_values(env, observation_space, action_space)
#     289
#     290     # ==== Check the render method and the declared render modes ====
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\env_checker.py in _check_returned_values(env, observation_space, action_space)
#     150                 raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     151     else:
# --> 152         _check_obs(obs, observation_space, "reset")
#     153
#     154     # Sample a random action
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\env_checker.py in _check_obs(obs, observation_space, method_name)
#     110         assert isinstance(obs, np.ndarray), f"The observation returned by `{method_name}()` method must be a numpy array"
#     111
# --> 112     assert observation_space.contains(
#     113         obs
#     114     ), f"The observation returned by the `{method_name}()` method does not match the given observation space"
#
# AssertionError: The observation returned by the `reset()` method does not match the given observation space

# %%
episodes = 50
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info, p = env.step(action)
        score+=reward
    print('Episode:{} Score:{} State:{} p:{}'.format(episode, score, n_state,p))
env.close()
# Out:
# Episode:1 Score:-1609.533001422882 State:80 p:-51.66999822854996
# Episode:2 Score:-1543.4179942131043 State:80 p:-53.03999948501587
# Episode:3 Score:-1490.8199931383133 State:80 p:-45.0099995136261
# Episode:4 Score:1226.197998213768 State:80 p:13.999999105930328
# Episode:5 Score:2152.687994027138 State:100 p:16.30999916791916
# Episode:6 Score:-1343.6440046548844 State:80 p:-0.37999898195266724
# Episode:7 Score:-1606.4290097832682 State:80 p:-32.41999953985214
# Episode:8 Score:1941.2600049972534 State:100 p:6.3899986743927
# Episode:9 Score:-1511.460014438629 State:80 p:-19.94000005722046
# Episode:10 Score:2386.559998512268 State:100 p:16.569998741149902
# Episode:11 Score:-1174.6219953298569 State:80 p:-15.489999532699585
# Episode:12 Score:-1309.7300105452537 State:80 p:-6.679999649524689
# Episode:13 Score:-1080.5039920628071 State:80 p:-15.209999084472656
# Episode:14 Score:1789.2899844646454 State:100 p:7.289999425411224
# Episode:15 Score:-985.1030048131943 State:80 p:-0.5100007653236389
# Episode:16 Score:-1205.5389969825744 State:80 p:-37.929999113082886
# Episode:17 Score:-1091.8229928016663 State:80 p:-29.399999141693115
# Episode:18 Score:-1586.5109883069993 State:80 p:-79.86999815702438
# Episode:19 Score:-1803.9389990448954 State:80 p:-50.59999817609787
# Episode:20 Score:2531.7999935746193 State:100 p:43.329998791217804
# Episode:21 Score:2181.0799980163574 State:[100] p:13.279999911785126
# Episode:22 Score:-994.2299993395806 State:80 p:-18.64999955892563
# Episode:23 Score:-948.280002450943 State:[80] p:-7.580000221729279
# Episode:24 Score:-1470.2219924926758 State:80 p:-38.179999589920044
# Episode:25 Score:-1389.36001226902 State:80 p:-23.639999330043793
# Episode:26 Score:-911.0199978113175 State:80 p:-0.14999955892562866
# Episode:27 Score:2388.6299962997437 State:[100] p:19.2399999499321
# Episode:28 Score:-1174.7389939308166 State:[80] p:-23.709999322891235
# Episode:29 Score:2267.9549992978573 State:100 p:49.97999835014343
# Episode:30 Score:2454.9799951314926 State:[100] p:29.689999043941498
# Episode:31 Score:-824.4520031929017 State:[80] p:-5.8500001430511475
# Episode:32 Score:2328.5949977338314 State:100 p:19.00999903678894
# Episode:33 Score:1426.8750079393387 State:80 p:2.2600008845329285
# Episode:34 Score:2412.8699948191643 State:100 p:7.239999830722809
# Episode:35 Score:2506.951993906498 State:100 p:32.93999844789505
# Episode:36 Score:2240.9320011377336 State:[99] p:21.9299995303154
# Episode:37 Score:-1536.4890048980712 State:80 p:-26.66999888420105
# Episode:38 Score:-1145.1759951233864 State:80 p:-24.08999925851822
# Episode:39 Score:-1275.1000007867813 State:80 p:-21.330000698566437
# Episode:40 Score:-1412.2309886932374 State:80 p:-39.059999227523804
# Episode:41 Score:1839.7249909698962 State:100 p:6.669998645782471
# Episode:42 Score:-916.5970075368881 State:80 p:-24.01000064611435
# Episode:43 Score:-1607.7629896640778 State:80 p:-103.10999894142151
# Episode:44 Score:-1343.2419873952865 State:80 p:-22.039998531341553
# Episode:45 Score:-1000.0189935445785 State:80 p:-37.919998705387115
# Episode:46 Score:1133.6129988610744 State:80 p:5.029999494552612
# Episode:47 Score:2303.1499984264374 State:100 p:4.250000178813934
# Episode:48 Score:797.7779883027076 State:80 p:5.139999806880951
# Episode:49 Score:-1552.0939913511277 State:[80] p:-31.139999449253082
# Episode:50 Score:-1654.7940128564835 State:80 p:-30.740000009536743

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, learning_rate=0.001, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\PPO_77
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -275     |
# | time/              |          |
# |    fps             | 575      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.7        |
# |    ep_rew_mean          | 292         |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011389356 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 5.27e-05    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.8e+05     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 7.4e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | 526         |
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010404745 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00874     |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.08e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 9.35e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.9          |
# |    ep_rew_mean          | 344           |
# | time/                   |               |
# |    fps                  | 322           |
# |    iterations           | 4             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00054792035 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | 0.0141        |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.36e+05      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000213     |
# |    value_loss           | 9.56e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.2        |
# |    ep_rew_mean          | 763         |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008399839 |
# |    clip_fraction        | 0.00566     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.0153      |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.89e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 7.89e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.1          |
# |    ep_rew_mean          | 353           |
# | time/                   |               |
# |    fps                  | 257           |
# |    iterations           | 6             |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00047205508 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | 0.0137        |
# |    learning_rate        | 0.001         |
# |    loss                 | 5.23e+05      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.000128      |
# |    value_loss           | 1.05e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 450          |
# | time/                   |              |
# |    fps                  | 226          |
# |    iterations           | 7            |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0074899886 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.04e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 7.68e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.7         |
# |    ep_rew_mean          | 736          |
# | time/                   |              |
# |    fps                  | 224          |
# |    iterations           | 8            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0034630203 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.023        |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.63e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 7.18e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.9         |
# |    ep_rew_mean          | 636          |
# | time/                   |              |
# |    fps                  | 221          |
# |    iterations           | 9            |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0008717597 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0.024        |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.52e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000279    |
# |    value_loss           | 8.68e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.6         |
# |    ep_rew_mean          | 792          |
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 10           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0015004373 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.026        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.78e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 7.6e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.5          |
# |    ep_rew_mean          | 788           |
# | time/                   |               |
# |    fps                  | 224           |
# |    iterations           | 11            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00022242437 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.937        |
# |    explained_variance   | 0.0307        |
# |    learning_rate        | 0.001         |
# |    loss                 | 5.6e+05       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -3.84e-05     |
# |    value_loss           | 8.96e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 722           |
# | time/                   |               |
# |    fps                  | 227           |
# |    iterations           | 12            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 3.9997103e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.95         |
# |    explained_variance   | 0.0295        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.39e+05      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | 5.79e-05      |
# |    value_loss           | 8.99e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.5         |
# |    ep_rew_mean          | 880          |
# | time/                   |              |
# |    fps                  | 227          |
# |    iterations           | 13           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0046484033 |
# |    clip_fraction        | 0.00347      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.0148       |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.51e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 7.97e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.8        |
# |    ep_rew_mean          | 583         |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 14          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004370123 |
# |    clip_fraction        | 0.00923     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.0298      |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.18e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 9.09e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | 621          |
# | time/                   |              |
# |    fps                  | 226          |
# |    iterations           | 15           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 5.067227e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.0106       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.35e+05     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000102    |
# |    value_loss           | 8.3e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.7         |
# |    ep_rew_mean          | 687          |
# | time/                   |              |
# |    fps                  | 226          |
# |    iterations           | 16           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0037397533 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.0504       |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.18e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 7.87e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.4          |
# |    ep_rew_mean          | 944           |
# | time/                   |               |
# |    fps                  | 227           |
# |    iterations           | 17            |
# |    time_elapsed         | 153           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00081546174 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.909        |
# |    explained_variance   | 0.0491        |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.38e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 6.93e-06      |
# |    value_loss           | 8.48e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.4         |
# |    ep_rew_mean          | 812          |
# | time/                   |              |
# |    fps                  | 227          |
# |    iterations           | 18           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0020261616 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.0404       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.33e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000886    |
# |    value_loss           | 9.29e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.4        |
# |    ep_rew_mean          | 877         |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 19          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003230785 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.0215      |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.47e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 9.57e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.9         |
# |    ep_rew_mean          | 710          |
# | time/                   |              |
# |    fps                  | 227          |
# |    iterations           | 20           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0004736195 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.0312       |
# |    learning_rate        | 0.001        |
# |    loss                 | 5.14e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000517    |
# |    value_loss           | 8.81e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.3          |
# |    ep_rew_mean          | 527           |
# | time/                   |               |
# |    fps                  | 228           |
# |    iterations           | 21            |
# |    time_elapsed         | 188           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00041404506 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.799        |
# |    explained_variance   | 0.0146        |
# |    learning_rate        | 0.001         |
# |    loss                 | 5.21e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000222     |
# |    value_loss           | 7.38e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.5          |
# |    ep_rew_mean          | 388           |
# | time/                   |               |
# |    fps                  | 228           |
# |    iterations           | 22            |
# |    time_elapsed         | 197           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00063496875 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.781        |
# |    explained_variance   | 0.0175        |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.53e+05      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000723     |
# |    value_loss           | 5.99e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.9          |
# |    ep_rew_mean          | 752           |
# | time/                   |               |
# |    fps                  | 228           |
# |    iterations           | 23            |
# |    time_elapsed         | 205           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00041968413 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.769        |
# |    explained_variance   | 0.051         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.14e+05      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 5.84e-05      |
# |    value_loss           | 5.63e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 765           |
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 24            |
# |    time_elapsed         | 214           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00042495527 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.784        |
# |    explained_variance   | 0.0612        |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.18e+05      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000576     |
# |    value_loss           | 6.95e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21            |
# |    ep_rew_mean          | 709           |
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 25            |
# |    time_elapsed         | 223           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00051471946 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.786        |
# |    explained_variance   | 0.061         |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.62e+05      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000681     |
# |    value_loss           | 7.65e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | 729          |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 26           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0006202184 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.0192       |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.22e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000585    |
# |    value_loss           | 6.48e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 653          |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 27           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0013286113 |
# |    clip_fraction        | 0.00278      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.836       |
# |    explained_variance   | 0.0578       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.57e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 7.39e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.2          |
# |    ep_rew_mean          | 586           |
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 28            |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00022565285 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.845        |
# |    explained_variance   | 0.0704        |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.66e+05      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000551     |
# |    value_loss           | 6.21e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21            |
# |    ep_rew_mean          | 645           |
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 29            |
# |    time_elapsed         | 258           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00040968278 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.826        |
# |    explained_variance   | 0.0597        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.7e+05       |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000443     |
# |    value_loss           | 6.18e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.7          |
# |    ep_rew_mean          | 815           |
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 30            |
# |    time_elapsed         | 267           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 5.5566168e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.824        |
# |    explained_variance   | 0.0601        |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.88e+05      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000176     |
# |    value_loss           | 6.53e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 636          |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 31           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 8.601812e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.0719       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.13e+05     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -6.53e-05    |
# |    value_loss           | 7.67e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.4         |
# |    ep_rew_mean          | 913          |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 32           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0020864038 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.84        |
# |    explained_variance   | 0.0591       |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.83e+05     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 6.29e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 523          |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 33           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0002818293 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.0434       |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.25e+05     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000459    |
# |    value_loss           | 8.66e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | 816          |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 34           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0006815469 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.0799       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.49e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000234    |
# |    value_loss           | 6.97e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.1          |
# |    ep_rew_mean          | 662           |
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 35            |
# |    time_elapsed         | 311           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00016187524 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.837        |
# |    explained_variance   | 0.0826        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.5e+05       |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 2.01e-05      |
# |    value_loss           | 7.17e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.2         |
# |    ep_rew_mean          | 618          |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 36           |
# |    time_elapsed         | 320          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 6.532209e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.0709       |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.08e+05     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -8.54e-05    |
# |    value_loss           | 6.37e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21           |
# |    ep_rew_mean          | 658          |
# | time/                   |              |
# |    fps                  | 230          |
# |    iterations           | 37           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0003296906 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.845       |
# |    explained_variance   | 0.0675       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3e+05        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000404    |
# |    value_loss           | 5.94e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 714           |
# | time/                   |               |
# |    fps                  | 231           |
# |    iterations           | 38            |
# |    time_elapsed         | 335           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 6.0057937e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.854        |
# |    explained_variance   | 0.0663        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.5e+05       |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -2.63e-05     |
# |    value_loss           | 6.7e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.5          |
# |    ep_rew_mean          | 904           |
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 39            |
# |    time_elapsed         | 342           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00012879021 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.851        |
# |    explained_variance   | 0.0686        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.33e+05      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -5.4e-05      |
# |    value_loss           | 7.25e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | 734          |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 40           |
# |    time_elapsed         | 350          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0002454064 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.0612       |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.57e+05     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00035     |
# |    value_loss           | 7.78e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.1          |
# |    ep_rew_mean          | 624           |
# | time/                   |               |
# |    fps                  | 234           |
# |    iterations           | 41            |
# |    time_elapsed         | 357           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00042967746 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.879        |
# |    explained_variance   | 0.0567        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.32e+05      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 7.11e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.2          |
# |    ep_rew_mean          | 463           |
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 42            |
# |    time_elapsed         | 365           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00010181713 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.883        |
# |    explained_variance   | 0.044         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.6e+05       |
# |    n_updates            | 410           |
# |    policy_gradient_loss | 7.41e-05      |
# |    value_loss           | 6.53e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 564          |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 43           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011170639 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.0909       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.24e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000385    |
# |    value_loss           | 6.57e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.7          |
# |    ep_rew_mean          | 766           |
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 44            |
# |    time_elapsed         | 382           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00011439543 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.908        |
# |    explained_variance   | 0.0929        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.33e+05      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | 2.64e-05      |
# |    value_loss           | 6.21e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21           |
# |    ep_rew_mean          | 659          |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 45           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 9.331011e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.0701       |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.02e+05     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 4.45e-05     |
# |    value_loss           | 7.15e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.4          |
# |    ep_rew_mean          | 451           |
# | time/                   |               |
# |    fps                  | 238           |
# |    iterations           | 46            |
# |    time_elapsed         | 394           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00013449285 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.89         |
# |    explained_variance   | 0.08          |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.7e+05       |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000173     |
# |    value_loss           | 6.7e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.1          |
# |    ep_rew_mean          | 663           |
# | time/                   |               |
# |    fps                  | 240           |
# |    iterations           | 47            |
# |    time_elapsed         | 400           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00077212614 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.905        |
# |    explained_variance   | 0.0832        |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.91e+05      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000786     |
# |    value_loss           | 5.6e+05       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 487          |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 48           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019556158 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0.0901       |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.41e+05     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000318    |
# |    value_loss           | 6.03e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.9          |
# |    ep_rew_mean          | 665           |
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 49            |
# |    time_elapsed         | 413           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 5.0396688e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.892        |
# |    explained_variance   | 0.0944        |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.8e+05       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -6.41e-05     |
# |    value_loss           | 6.71e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 466          |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 50           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0009599316 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | 0.0896       |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.63e+05     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -6.97e-05    |
# |    value_loss           | 6.79e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.6          |
# |    ep_rew_mean          | 769           |
# | time/                   |               |
# |    fps                  | 245           |
# |    iterations           | 51            |
# |    time_elapsed         | 425           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 5.3718162e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.91         |
# |    explained_variance   | 0.0807        |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.99e+05      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -5.26e-05     |
# |    value_loss           | 6.72e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.7          |
# |    ep_rew_mean          | 661           |
# | time/                   |               |
# |    fps                  | 246           |
# |    iterations           | 52            |
# |    time_elapsed         | 431           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00012133035 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.909        |
# |    explained_variance   | 0.103         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.85e+05      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000152     |
# |    value_loss           | 7.64e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 696           |
# | time/                   |               |
# |    fps                  | 247           |
# |    iterations           | 53            |
# |    time_elapsed         | 437           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 6.2181876e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.91         |
# |    explained_variance   | 0.0886        |
# |    learning_rate        | 0.001         |
# |    loss                 | 4.01e+05      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -2.17e-05     |
# |    value_loss           | 7.84e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.5         |
# |    ep_rew_mean          | 826          |
# | time/                   |              |
# ...
# |    clip_fraction        | 0.00615     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.57e+05    |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00159    |
# |    value_loss           | 6.04e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.1         |
# |    ep_rew_mean          | 617          |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 180          |
# |    time_elapsed         | 1229         |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0023561679 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.25e+05     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 7.03e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.5          |
# |    ep_rew_mean          | 941           |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 181           |
# |    time_elapsed         | 1235          |
# |    total_timesteps      | 370688        |
# | train/                  |               |
# |    approx_kl            | 0.00029130906 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.899        |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.26e+05      |
# |    n_updates            | 1800          |
# |    policy_gradient_loss | -0.000256     |
# |    value_loss           | 6.16e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.9          |
# |    ep_rew_mean          | 692           |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 182           |
# |    time_elapsed         | 1241          |
# |    total_timesteps      | 372736        |
# | train/                  |               |
# |    approx_kl            | 8.5084175e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.89         |
# |    explained_variance   | 0.141         |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.67e+05      |
# |    n_updates            | 1810          |
# |    policy_gradient_loss | 2.71e-05      |
# |    value_loss           | 6.44e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.6         |
# |    ep_rew_mean          | 884          |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 183          |
# |    time_elapsed         | 1247         |
# |    total_timesteps      | 374784       |
# | train/                  |              |
# |    approx_kl            | 9.457051e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.13e+05     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -8.5e-05     |
# |    value_loss           | 5.94e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21           |
# |    ep_rew_mean          | 554          |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 184          |
# |    time_elapsed         | 1253         |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 9.602605e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.33e+05     |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -3.44e-05    |
# |    value_loss           | 6.13e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.2          |
# |    ep_rew_mean          | 523           |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 185           |
# |    time_elapsed         | 1260          |
# |    total_timesteps      | 378880        |
# | train/                  |               |
# |    approx_kl            | 0.00012868943 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.895        |
# |    explained_variance   | 0.158         |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.52e+05      |
# |    n_updates            | 1840          |
# |    policy_gradient_loss | -0.000227     |
# |    value_loss           | 6.72e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21            |
# |    ep_rew_mean          | 653           |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 186           |
# |    time_elapsed         | 1266          |
# |    total_timesteps      | 380928        |
# | train/                  |               |
# |    approx_kl            | 0.00010419774 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.903        |
# |    explained_variance   | 0.139         |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.25e+05      |
# |    n_updates            | 1850          |
# |    policy_gradient_loss | -0.000143     |
# |    value_loss           | 6.01e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 850           |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 187           |
# |    time_elapsed         | 1272          |
# |    total_timesteps      | 382976        |
# | train/                  |               |
# |    approx_kl            | 0.00067215017 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.89         |
# |    explained_variance   | 0.138         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.72e+05      |
# |    n_updates            | 1860          |
# |    policy_gradient_loss | -0.000935     |
# |    value_loss           | 6.2e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.2          |
# |    ep_rew_mean          | 1.05e+03      |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 188           |
# |    time_elapsed         | 1278          |
# |    total_timesteps      | 385024        |
# | train/                  |               |
# |    approx_kl            | 9.1707625e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.887        |
# |    explained_variance   | 0.129         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.58e+05      |
# |    n_updates            | 1870          |
# |    policy_gradient_loss | -2.45e-06     |
# |    value_loss           | 5.51e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.2         |
# |    ep_rew_mean          | 520          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 189          |
# |    time_elapsed         | 1284         |
# |    total_timesteps      | 387072       |
# | train/                  |              |
# |    approx_kl            | 0.0010905338 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.81e+05     |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.000217    |
# |    value_loss           | 6.68e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.4          |
# |    ep_rew_mean          | 374           |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 190           |
# |    time_elapsed         | 1290          |
# |    total_timesteps      | 389120        |
# | train/                  |               |
# |    approx_kl            | 0.00017071492 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.893        |
# |    explained_variance   | 0.157         |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.24e+05      |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | -0.000101     |
# |    value_loss           | 6.16e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.3         |
# |    ep_rew_mean          | 942          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 191          |
# |    time_elapsed         | 1297         |
# |    total_timesteps      | 391168       |
# | train/                  |              |
# |    approx_kl            | 0.0006161474 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.89e+05     |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 6.07e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | 705          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 192          |
# |    time_elapsed         | 1303         |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 4.141219e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.907       |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.001        |
# |    loss                 | 4.28e+05     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -1.9e-05     |
# |    value_loss           | 7.24e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 715           |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 193           |
# |    time_elapsed         | 1309          |
# |    total_timesteps      | 395264        |
# | train/                  |               |
# |    approx_kl            | 0.00047337235 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.9          |
# |    explained_variance   | 0.149         |
# |    learning_rate        | 0.001         |
# |    loss                 | 3.59e+05      |
# |    n_updates            | 1920          |
# |    policy_gradient_loss | -0.000702     |
# |    value_loss           | 6.55e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21           |
# |    ep_rew_mean          | 640          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 194          |
# |    time_elapsed         | 1316         |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 7.396535e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.9         |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.001        |
# |    loss                 | 3.03e+05     |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | 1.66e-05     |
# |    value_loss           | 6.56e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.8          |
# |    ep_rew_mean          | 736           |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 195           |
# |    time_elapsed         | 1322          |
# |    total_timesteps      | 399360        |
# | train/                  |               |
# |    approx_kl            | 1.3886485e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.906        |
# |    explained_variance   | 0.135         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.44e+05      |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | -5.72e-05     |
# |    value_loss           | 5.99e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 20.6          |
# |    ep_rew_mean          | 887           |
# | time/                   |               |
# |    fps                  | 302           |
# |    iterations           | 196           |
# |    time_elapsed         | 1328          |
# |    total_timesteps      | 401408        |
# | train/                  |               |
# |    approx_kl            | 2.7269794e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.903        |
# |    explained_variance   | 0.137         |
# |    learning_rate        | 0.001         |
# |    loss                 | 2.83e+05      |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -8.35e-05     |
# |    value_loss           | 6.34e+05      |
# -------------------------------------------

# %%
#evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
#model.save('PPO')

# %%
episodes = 100
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action, _states = model.predict(obs)
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{} State:{}'.format(episode, score, n_state))
env.close()
# Out:
# Episode:1 Score:398.5720014810562 State:80
# Episode:2 Score:437.7120009899139 State:80
# Episode:3 Score:-1157.1280219316482 State:80
# Episode:4 Score:335.4770023226738 State:80
# Episode:5 Score:-1668.4480102419852 State:80
# Episode:6 Score:-771.23898999691 State:80
# Episode:7 Score:2503.5419944763185 State:100
# Episode:8 Score:-1231.1779921412467 State:80
# Episode:9 Score:-956.5680038690567 State:80
# Episode:10 Score:2329.9399967193604 State:[100]
# Episode:11 Score:-1351.0959739208222 State:80
# Episode:12 Score:-1542.0749986052513 State:80
# Episode:13 Score:1899.6000027656555 State:100
# Episode:14 Score:2346.9660001277925 State:100
# Episode:15 Score:209.9280012726784 State:[80]
# Episode:16 Score:-1035.4280193805694 State:80
# Episode:17 Score:-1376.7200158596038 State:80
# Episode:18 Score:-1377.2380139589309 State:80
# Episode:19 Score:191.27800159454347 State:[80]
# Episode:20 Score:1900.030002772808 State:100
# Episode:21 Score:-1085.9230110645294 State:80
# Episode:22 Score:-1359.918018555641 State:80
# Episode:23 Score:-561.3029968738556 State:80
# Episode:24 Score:2276.9699987769127 State:100
# Episode:25 Score:-1385.783005297184 State:80
# Episode:26 Score:1705.449984550476 State:100
# Episode:27 Score:1940.920002579689 State:100
# Episode:28 Score:2346.9660001277925 State:100
# Episode:29 Score:1973.8899974822998 State:100
# Episode:30 Score:-1230.4000179886818 State:80
# Episode:31 Score:-1673.3990065932276 State:80
# Episode:32 Score:-1479.9180077075957 State:80
# Episode:33 Score:-827.2179996728897 State:80
# Episode:34 Score:2173.6169959425924 State:100
# Episode:35 Score:-1824.8250046849253 State:80
# Episode:36 Score:-1614.603001177311 State:80
# Episode:37 Score:2522.8099932074547 State:[100]
# Episode:38 Score:-1369.2920135974884 State:80
# Episode:39 Score:209.9280012726784 State:[80]
# Episode:40 Score:-1626.9429966807365 State:80
# Episode:41 Score:-1278.559988617897 State:80
# Episode:42 Score:1879.2400033473969 State:100
# Episode:43 Score:1843.0200021266937 State:100
# Episode:44 Score:-1643.8249839782716 State:80
# Episode:45 Score:2528.1059965252875 State:100
# Episode:46 Score:1843.0200021266937 State:100
# Episode:47 Score:1843.0200021266937 State:100
# Episode:48 Score:312.3380005836487 State:[80]
# Episode:49 Score:-114.01901983022688 State:80
# Episode:50 Score:408.90200182199476 State:80
# Episode:51 Score:209.9280012726784 State:[80]
# Episode:52 Score:160.38199635744095 State:80
# Episode:53 Score:-1169.0190062999725 State:80
# Episode:54 Score:209.9280012726784 State:[80]
# Episode:55 Score:-1068.707017326355 State:80
# Episode:56 Score:2491.8859953045844 State:100
# Episode:57 Score:-1350.8030107617378 State:80
# Episode:58 Score:209.9280012726784 State:[80]
# Episode:59 Score:-934.1129941940308 State:80
# Episode:60 Score:-1664.118013715744 State:80
# Episode:61 Score:-1145.0030102729797 State:80
# Episode:62 Score:-791.6729967832565 State:80
# Episode:63 Score:2204.6999994516373 State:100
# Episode:64 Score:-1013.4780193924904 State:80
# Episode:65 Score:-1013.4780193924904 State:80
# Episode:66 Score:214.85000249147416 State:[80]
# Episode:67 Score:-1754.1950082659723 State:80
# Episode:68 Score:2528.1059965252875 State:100
# Episode:69 Score:1879.2400033473969 State:100
# Episode:70 Score:-1636.0480177760126 State:80
# Episode:71 Score:2045.87999689579 State:100
# Episode:72 Score:-1304.607994890213 State:80
# Episode:73 Score:-1463.8540026664734 State:80
# Episode:74 Score:-617.9449971795082 State:80
# Episode:75 Score:2363.2499974370003 State:[100]
# Episode:76 Score:-1174.3629913330078 State:80
# Episode:77 Score:1879.2400033473969 State:100
# Episode:78 Score:-1652.7590045213701 State:80
# Episode:79 Score:2143.46999502182 State:100
# Episode:80 Score:2068.6699818968773 State:100
# Episode:81 Score:-990.9399988412857 State:[80]
# Episode:82 Score:-1412.3350093841552 State:80
# Episode:83 Score:1879.2400033473969 State:100
# Episode:84 Score:2619.945996809006 State:100
# Episode:85 Score:-1070.9850151896476 State:80
# Episode:86 Score:-759.4649897098541 State:80
# Episode:87 Score:-1504.5580076932906 State:80
# Episode:88 Score:2528.1059965252875 State:100
# Episode:89 Score:172.37200548648835 State:80
# Episode:90 Score:180.57699429988864 State:80
# Episode:91 Score:191.27800159454347 State:[80]
# Episode:92 Score:2439.9999935626984 State:[100]
# Episode:93 Score:-1307.872992515564 State:80
# Episode:94 Score:-934.074001288414 State:80
# Episode:95 Score:2528.1059965252875 State:100
# Episode:96 Score:-1259.5120126724244 State:80
# Episode:97 Score:178.88799797296525 State:[80]
# Episode:98 Score:2159.4999947547913 State:100
# Episode:99 Score:-1600.5850148081781 State:80
# Episode:100 Score:-1781.4780020475387 State:80

# %%
env.close()

# %%
#Save the model
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load('PPO_model', env=env)

# %%
#View logs in Tensorboard
training_log_path = os.path.join(log_path, 'PPO')
# !tensorboard --logdir={training_log_path}
