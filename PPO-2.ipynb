# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[181, 224,   1],
#        [112,  34, 230],
#        [168,  73, 240]])

# %%
class ChargeEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Observation box
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start SOC
        self.state = 20 + random.randint(-3,3)
        # Set max SOC
        self.max_state = 100
        # Set power
        self.power = 20
        # Set price data
        self.priceArray = np.float32(np.array([36.22, 27.98, 4.6, 9.38, -0.43, 2.26, 4.02, 8.48, 18.73,
                                               20.64, 22.99, 18.93, 16.67, 9.51, 3.59, 2.31, 2.78, 6.3, 14.18,
                                               16.11, 21.42, 25.87, 30.71, 18.44]))
        # Set current index
        self.currentIndex = 0
        self.currentprice = 0
        # Set temp 
        self.temp = 0
        self.change = 0
        # Set median
        self.mid = np.median(self.priceArray)
        self.open = 0
        self.rate = 0
        # Set total time 
        self.time = 23 
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 sell
        # 1 -1 = 0 hold
        # 2 -1 = 1 buy 
       
        self.currentprice = self.priceArray[self.currentIndex]
        # Reduce time by 1 h
        self.time -= 1 
        
        # If state exceeds boundaries after the action due to power limit, set state to 100 or 0
        if 100 < self.state < (self.max_state + self.power):
            self.rate = (self.state - self.max_state) / self.power
            self.state = 100
            #action = 0
        elif (0 - self.power) < self.state < 0:
            self.rate = (0 - self.state) / self.power
            self.state = 0
            #action = 2
        else: 
            self.rate = 1
        
        #if self.state >= 90 and len(self.priceArray - 1) - self.currentIndex < 2:
        #    action = 1
        #elif (self.max_state - self.state) / self.power >= len(self.priceArray - 1) - self.currentIndex:
        #    action = 2
        
        # Lose money when buy, and get when sell
        self.temp = -abs(self.currentprice) * (action - 1) * self.rate
        
        # Calculate cumulative profit
        self.change += self.temp
        
        # Give reward based on the profit
        if self.change >= 0: 
            reward = 1
        else:
            reward = -1
            
        # Update the state
        self.state += (action - 1) * self.power 
        
        # Move to the next price
        self.currentIndex += 1
        
        # Set Low boundary and Up boundary
        #Set end state
        if self.time <= 0: 
            done = True
            if self.state < 80:
                done = True
                reward = -1000
        elif self.state <= -20 or self.state >= 120:
            done = True
            reward = -1000
        else:
            done = False       

        

        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([20 + random.randint(-3,3)])#.astype(float)
        # Set max SOC
        self.max_state = 100
        # Set power
        self.power = 20
        # Set price data
        self.priceArray = np.float32(np.array([36.22, 27.98, 4.6, 9.38, -0.43, 2.26, 4.02, 8.48, 18.73,
                                               20.64, 22.99, 18.93, 16.67, 9.51, 3.59, 2.31, 2.78, 6.3, 14.18,
                                               16.11, 21.42, 25.87, 30.71, 18.44]))
        # Set current index
        self.currentIndex = 0
        self.currentprice = 0
        # Set temp 
        self.temp = 0
        self.change = 0
        self.rate = 0
        # Set median
        self.mid = np.median(self.priceArray)
        self.open = 0
        # Set total time 
        self.time = 23 
        return self.state

# %%
env=ChargeEnv()

# %%
env.observation_space.sample()
# Out:
# array([25.448338], dtype=float32)

# %%
env.reset()
# Out:
# array([23])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11764\1913415460.py in <module>
# ----> 1 check_env(env, warn=True)
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\env_checker.py in check_env(env, warn, skip_render_check)
#     286
#     287     # ============ Check the returned values ===============
# --> 288     _check_returned_values(env, observation_space, action_space)
#     289
#     290     # ==== Check the render method and the declared render modes ====
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\env_checker.py in _check_returned_values(env, observation_space, action_space)
#     150                 raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     151     else:
# --> 152         _check_obs(obs, observation_space, "reset")
#     153
#     154     # Sample a random action
#
# ~\AppData\Roaming\Python\Python39\site-packages\stable_baselines3\common\env_checker.py in _check_obs(obs, observation_space, method_name)
#     110         assert isinstance(obs, np.ndarray), f"The observation returned by `{method_name}()` method must be a numpy array"
#     111
# --> 112     assert observation_space.contains(
#     113         obs
#     114     ), f"The observation returned by the `{method_name}()` method does not match the given observation space"
#
# AssertionError: The observation returned by the `reset()` method does not match the given observation space

# %%
episodes = 50
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{} State:{}'.format(episode, score, n_state))
env.close()
# Out:
# Episode:1 Score:-988 State:-20
# Episode:2 Score:-1014 State:[-20]
# Episode:3 Score:-1018 State:-20
# Episode:4 Score:-1007 State:[-20]
# Episode:5 Score:-1018 State:[77]
# Episode:6 Score:-1017 State:-20
# Episode:7 Score:-997 State:-20
# Episode:8 Score:-995 State:[-20]
# Episode:9 Score:-1011 State:-20
# Episode:10 Score:-990 State:[-20]
# Episode:11 Score:23 State:100
# Episode:12 Score:-992 State:-20
# Episode:13 Score:-1022 State:[42]
# Episode:14 Score:-1009 State:120
# Episode:15 Score:-1005 State:-20
# Episode:16 Score:-981 State:120
# Episode:17 Score:-1011 State:[120]
# Episode:18 Score:-1018 State:-20
# Episode:19 Score:-1005 State:-20
# Episode:20 Score:-999 State:[-20]
# Episode:21 Score:-999 State:-20
# Episode:22 Score:-999 State:-20
# Episode:23 Score:-999 State:[-20]
# Episode:24 Score:-999 State:-20
# Episode:25 Score:-1009 State:120
# Episode:26 Score:-999 State:-20
# Episode:27 Score:-998 State:-20
# Episode:28 Score:-997 State:[-20]
# Episode:29 Score:-1004 State:-20
# Episode:30 Score:-995 State:-20
# Episode:31 Score:-1018 State:120
# Episode:32 Score:-1011 State:[120]
# Episode:33 Score:-1022 State:0
# Episode:34 Score:-7 State:[102]
# Episode:35 Score:-980 State:40
# Episode:36 Score:-1001 State:-20
# Episode:37 Score:-19 State:100
# Episode:38 Score:-23 State:[119]
# Episode:39 Score:-988 State:120
# Episode:40 Score:-999 State:-20
# Episode:41 Score:-1007 State:-20
# Episode:42 Score:-987 State:-20
# Episode:43 Score:-1018 State:-20
# Episode:44 Score:-999 State:-20
# Episode:45 Score:-994 State:-20
# Episode:46 Score:-989 State:120
# Episode:47 Score:-1020 State:0
# Episode:48 Score:-1006 State:120
# Episode:49 Score:-1007 State:120
# Episode:50 Score:-995 State:-20

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, learning_rate=0.0001, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500000)
# Out:
# Logging to Training\Logs\PPO_35
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | -943     |
# | time/              |          |
# |    fps             | 587      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -885        |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010261548 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000861    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.14e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 3.85e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15          |
# |    ep_rew_mean          | -895        |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010001058 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00314    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.95e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 3.77e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.3        |
# |    ep_rew_mean          | -837        |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008471144 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00344    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.67e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 3.65e+05    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 17.5      |
# |    ep_rew_mean          | -835      |
# | time/                   |           |
# |    fps                  | 364       |
# |    iterations           | 5         |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0143055 |
# |    clip_fraction        | 0.000342  |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | -0.00431  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 1.45e+05  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.00552  |
# |    value_loss           | 3.27e+05  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | -767        |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 6           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004580063 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | -0.00471    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.53e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 3.09e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17          |
# |    ep_rew_mean          | -856        |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 7           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010124004 |
# |    clip_fraction        | 0.00898     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | -0.00288    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.29e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 2.92e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.5         |
# |    ep_rew_mean          | -807         |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 8            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0076415623 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | -0.00388     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.51e+05     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00555     |
# |    value_loss           | 3.19e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | -728        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 9           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005188282 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | -0.00235    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.58e+05    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 2.96e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.5         |
# |    ep_rew_mean          | -630         |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 10           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0044648047 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | -0.00228     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.35e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00643     |
# |    value_loss           | 2.51e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.8         |
# |    ep_rew_mean          | -711         |
# | time/                   |              |
# |    fps                  | 345          |
# |    iterations           | 11           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0014151854 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | -0.000866    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.68e+04     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 2.11e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.5         |
# |    ep_rew_mean          | -641         |
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 12           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0064164945 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.624       |
# |    explained_variance   | -0.00104     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.24e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00638     |
# |    value_loss           | 2.46e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.3         |
# |    ep_rew_mean          | -601         |
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 13           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0012992074 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.607       |
# |    explained_variance   | -0.000127    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.11e+05     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000906    |
# |    value_loss           | 2.1e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.2         |
# |    ep_rew_mean          | -583         |
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 14           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0009157581 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | -0.00106     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.26e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 1.96e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.5          |
# |    ep_rew_mean          | -583          |
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 15            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00017734763 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.579        |
# |    explained_variance   | -9.14e-05     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 9.92e+04      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000779     |
# |    value_loss           | 1.89e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.5         |
# |    ep_rew_mean          | -512         |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 16           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0006620953 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | -7.72e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 8.91e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 1.93e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | -554        |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 17          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002485014 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | -0.00085    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.89e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00078    |
# |    value_loss           | 1.6e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.9        |
# |    ep_rew_mean          | -564        |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 18          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004555089 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | -0.000467   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.89e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00774    |
# |    value_loss           | 1.84e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22          |
# |    ep_rew_mean          | -592        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 19          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004012473 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | -0.000165   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.82e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00312    |
# |    value_loss           | 1.83e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | -563         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 20           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0028287186 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.552       |
# |    explained_variance   | -0.000188    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.55e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00656     |
# |    value_loss           | 1.93e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | -485         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 21           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0045178076 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | -2.48e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.86e+04     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 1.78e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.7         |
# |    ep_rew_mean          | -553         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 22           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0025537964 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | -0.000257    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.55e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 1.55e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 21.8          |
# |    ep_rew_mean          | -592          |
# | time/                   |               |
# |    fps                  | 332           |
# |    iterations           | 23            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00058298314 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.503        |
# |    explained_variance   | -9.06e-06     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.82e+04      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000772     |
# |    value_loss           | 1.79e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.5         |
# |    ep_rew_mean          | -562         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 24           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0029140497 |
# |    clip_fraction        | 0.00674      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | -5.36e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 8.58e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 1.86e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -554         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 25           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024425937 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 2.92e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.05e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 1.84e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21          |
# |    ep_rew_mean          | -594        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 26          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.002673964 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.54e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 1.73e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.2         |
# |    ep_rew_mean          | -545         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 27           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0033611292 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | -0.000318    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.08e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 1.84e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.6         |
# |    ep_rew_mean          | -496         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 28           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0027183471 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | 1.37e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 8.78e+04     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 1.62e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.2         |
# |    ep_rew_mean          | -416         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 29           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0018697511 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | -1.12e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.6e+04      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 1.51e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | -444        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 30          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004573132 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.18e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 1.22e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.6         |
# |    ep_rew_mean          | -546         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 31           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0018989067 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | -1.67e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.83e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000496    |
# |    value_loss           | 1.37e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.1       |
# |    ep_rew_mean          | -396       |
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 32         |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00265359 |
# |    clip_fraction        | 0.0111     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.471     |
# |    explained_variance   | -3.58e-07  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 8.74e+04   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00244   |
# |    value_loss           | 1.58e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.5         |
# |    ep_rew_mean          | -457         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 33           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0009413446 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.467       |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.23e+04     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000581    |
# |    value_loss           | 1.07e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.3         |
# |    ep_rew_mean          | -407         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 34           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0029595585 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 2.32e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.01e+04     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 1.35e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.9       |
# |    ep_rew_mean          | -516       |
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 35         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.00410303 |
# |    clip_fraction        | 0.0343     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.459     |
# |    explained_variance   | -9.42e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 5.34e+04   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.00574   |
# |    value_loss           | 1.23e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.5         |
# |    ep_rew_mean          | -387         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 36           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0024592797 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | -3.1e-06     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.68e+04     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 1.5e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.7         |
# |    ep_rew_mean          | -358         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 37           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0027263633 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.48e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 1.13e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.1       |
# |    ep_rew_mean          | -528       |
# | time/                   |            |
# |    fps                  | 332        |
# |    iterations           | 38         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00281408 |
# |    clip_fraction        | 0.0136     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.425     |
# |    explained_variance   | -3.58e-06  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 6.48e+04   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00171   |
# |    value_loss           | 1.06e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | -478        |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 39          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002960891 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.5e+04     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 1.59e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -378         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 40           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0024049967 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.426       |
# |    explained_variance   | 5.36e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.28e+04     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 1.43e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.3         |
# |    ep_rew_mean          | -378         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 41           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0022047285 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | -1.91e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.19e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 1.15e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.9         |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 42           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 9.419644e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.94e+04     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000211    |
# |    value_loss           | 1.1e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.7         |
# |    ep_rew_mean          | -368         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 43           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0014107511 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | -1.67e-06    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.11e+04     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 1.11e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | -389        |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 44          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002905485 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.461      |
# |    explained_variance   | -0.000353   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.81e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 1.02e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.5       |
# |    ep_rew_mean          | -309       |
# | time/                   |            |
# |    fps                  | 333        |
# |    iterations           | 45         |
# |    time_elapsed         | 276        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00315545 |
# |    clip_fraction        | 0.0176     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.472     |
# |    explained_variance   | 5.36e-07   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 5.92e+04   |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00193   |
# |    value_loss           | 1.11e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.8         |
# |    ep_rew_mean          | -349         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 46           |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0039362526 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.97e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00914     |
# |    value_loss           | 8.32e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.2         |
# |    ep_rew_mean          | -458         |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 47           |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0016365574 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.392       |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.41e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 9.65e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -309         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 48           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019365965 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.443       |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.66e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 1.26e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 49          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.001477407 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.385      |
# |    explained_variance   | -5.77e-05   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.13e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000876   |
# |    value_loss           | 7.69e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22           |
# |    ep_rew_mean          | -310         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 50           |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0019433511 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.07e+04     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.00221      |
# |    value_loss           | 8.35e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.6         |
# |    ep_rew_mean          | -240         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 51           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0025389714 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.27e+04     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 8.54e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | -450        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 52          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009770527 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.02e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00115     |
# |    value_loss           | 6.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.3        |
# |    ep_rew_mean          | -281        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 53          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.002118292 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.429      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.78e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 1.23e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.8         |
# |    ep_rew_mean          | -280         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 54           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0048217922 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.409       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.88e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.00224      |
# |    value_loss           | 6.35e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | -280        |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 55          |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | -42.9       |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 228         |
# |    time_elapsed         | 1591        |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.004209063 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.102      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.28e+03    |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.000699   |
# |    value_loss           | 1.21e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23         |
# |    ep_rew_mean          | -183       |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 229        |
# |    time_elapsed         | 1599       |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.07754605 |
# |    clip_fraction        | 0.0482     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.107     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0001     |
# |    loss                 | 482        |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | 0.00176    |
# |    value_loss           | 7.95e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.8       |
# |    ep_rew_mean          | -62.7      |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 230        |
# |    time_elapsed         | 1607       |
# |    total_timesteps      | 471040     |
# | train/                  |            |
# |    approx_kl            | 0.12449584 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.253     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.51e+04   |
# |    n_updates            | 2290       |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 5.77e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.9       |
# |    ep_rew_mean          | -143       |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 231        |
# |    time_elapsed         | 1614       |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.01728965 |
# |    clip_fraction        | 0.0416     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.101     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.13e+03   |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | 0.00117    |
# |    value_loss           | 1.03e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | -23         |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 232         |
# |    time_elapsed         | 1621        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.061042078 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.257      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.17e+04    |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 4.31e+04    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 22.7          |
# |    ep_rew_mean          | -52.7         |
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 233           |
# |    time_elapsed         | 1629          |
# |    total_timesteps      | 477184        |
# | train/                  |               |
# |    approx_kl            | 0.00084014377 |
# |    clip_fraction        | 0.0163        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.144        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 473           |
# |    n_updates            | 2320          |
# |    policy_gradient_loss | 0.000354      |
# |    value_loss           | 1.01e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23            |
# |    ep_rew_mean          | -33           |
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 234           |
# |    time_elapsed         | 1637          |
# |    total_timesteps      | 479232        |
# | train/                  |               |
# |    approx_kl            | 0.00076306093 |
# |    clip_fraction        | 0.0382        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.111        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0001        |
# |    loss                 | 8.4e+03       |
# |    n_updates            | 2330          |
# |    policy_gradient_loss | 0.00132       |
# |    value_loss           | 9.63e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -62.5       |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 235         |
# |    time_elapsed         | 1645        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.003708621 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 440         |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | 0.0034      |
# |    value_loss           | 4.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | -42.7       |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 236         |
# |    time_elapsed         | 1652        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.014008158 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0596     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 9.51e-06    |
# |    value_loss           | 1.24e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | -52.7       |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 237         |
# |    time_elapsed         | 1660        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.001130484 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 421         |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.000946    |
# |    value_loss           | 3.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | -23         |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 238         |
# |    time_elapsed         | 1667        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.012339174 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.158      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 878         |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.00429     |
# |    value_loss           | 6.87e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 23            |
# |    ep_rew_mean          | -33           |
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 239           |
# |    time_elapsed         | 1675          |
# |    total_timesteps      | 489472        |
# | train/                  |               |
# |    approx_kl            | 3.7715537e-05 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.127        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 312           |
# |    n_updates            | 2380          |
# |    policy_gradient_loss | 0.000477      |
# |    value_loss           | 632           |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23         |
# |    ep_rew_mean          | -23        |
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 240        |
# |    time_elapsed         | 1682       |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.04389923 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.203     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.15e+03   |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | -0.00149   |
# |    value_loss           | 4.22e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.7         |
# |    ep_rew_mean          | -42.7        |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 241          |
# |    time_elapsed         | 1690         |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0008037207 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.106       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 287          |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.000541    |
# |    value_loss           | 511          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | -42.7       |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 242         |
# |    time_elapsed         | 1697        |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.001205693 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0969     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 169         |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | 0.00117     |
# |    value_loss           | 5.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | -92.8       |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 243         |
# |    time_elapsed         | 1705        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.009953354 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.103      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 158         |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 0.00933     |
# |    value_loss           | 2.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -42.9       |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 244         |
# |    time_elapsed         | 1713        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.041273076 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.245      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.04e+04    |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 2.26e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23           |
# |    ep_rew_mean          | -33          |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 245          |
# |    time_elapsed         | 1720         |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0037429468 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.38e+03     |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | 0.00553      |
# |    value_loss           | 7.53e+03     |
# ------------------------------------------

# %%
#evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
#model.save('PPO')

# %%
episodes = 100
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action, _states = model.predict(obs)
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{} State:{}'.format(episode, score, n_state))
env.close()
# Out:
# Episode:1 Score:-1010 State:120
# Episode:2 Score:-7 State:100
# Episode:3 Score:-23 State:[99]
# Episode:4 Score:-19 State:100
# Episode:5 Score:-21 State:100
# Episode:6 Score:-1015 State:120
# Episode:7 Score:-1014 State:120
# Episode:8 Score:-19 State:100
# Episode:9 Score:-1013 State:[120]
# Episode:10 Score:-1012 State:[62]
# Episode:11 Score:-1016 State:[77]
# Episode:12 Score:-1011 State:120
# Episode:13 Score:-21 State:[100]
# Episode:14 Score:-19 State:100
# Episode:15 Score:-15 State:100
# Episode:16 Score:-21 State:[83]
# Episode:17 Score:-23 State:[98]
# Episode:18 Score:-23 State:[80]
# Episode:19 Score:-988 State:[43]
# Episode:20 Score:-1020 State:[57]
# Episode:21 Score:-11 State:[100]
# Episode:22 Score:-21 State:[83]
# Episode:23 Score:-1022 State:[77]
# Episode:24 Score:-3 State:120
# Episode:25 Score:-1012 State:[78]
# Episode:26 Score:-1016 State:[120]
# Episode:27 Score:-1015 State:120
# Episode:28 Score:-17 State:[103]
# Episode:29 Score:-21 State:[99]
# Episode:30 Score:-1010 State:[120]
# Episode:31 Score:-19 State:100
# Episode:32 Score:-19 State:100
# Episode:33 Score:-21 State:[97]
# Episode:34 Score:-1016 State:[61]
# Episode:35 Score:-15 State:100
# Episode:36 Score:-5 State:[97]
# Episode:37 Score:-990 State:-20
# Episode:38 Score:-988 State:[38]
# Episode:39 Score:-7 State:100
# Episode:40 Score:-1022 State:[60]
# Episode:41 Score:-1018 State:120
# Episode:42 Score:-1020 State:[62]
# Episode:43 Score:-23 State:[98]
# Episode:44 Score:-21 State:[100]
# Episode:45 Score:-15 State:[99]
# Episode:46 Score:-23 State:100
# Episode:47 Score:-9 State:[81]
# Episode:48 Score:-23 State:[80]
# Episode:49 Score:-1016 State:[77]
# Episode:50 Score:-9 State:[100]
# Episode:51 Score:-23 State:80
# Episode:52 Score:-1010 State:120
# Episode:53 Score:-1020 State:[62]
# Episode:54 Score:-1018 State:[79]
# Episode:55 Score:-1004 State:[77]
# Episode:56 Score:-1012 State:[61]
# Episode:57 Score:-23 State:[83]
# Episode:58 Score:-1014 State:[120]
# Episode:59 Score:-5 State:[81]
# Episode:60 Score:-1018 State:120
# Episode:61 Score:-1010 State:[62]
# Episode:62 Score:-996 State:[58]
# Episode:63 Score:-23 State:[81]
# Episode:64 Score:-7 State:[81]
# Episode:65 Score:-1022 State:[79]
# Episode:66 Score:-1018 State:120
# Episode:67 Score:-23 State:[120]
# Episode:68 Score:-19 State:80
# Episode:69 Score:-1010 State:120
# Episode:70 Score:-19 State:[100]
# Episode:71 Score:-1012 State:[62]
# Episode:72 Score:-1022 State:[60]
# Episode:73 Score:-23 State:100
# Episode:74 Score:-21 State:100
# Episode:75 Score:-1020 State:[62]
# Episode:76 Score:-13 State:[83]
# Episode:77 Score:-9 State:100
# Episode:78 Score:-1000 State:[60]
# Episode:79 Score:-23 State:[98]
# Episode:80 Score:-21 State:[98]
# Episode:81 Score:-21 State:[103]
# Episode:82 Score:-15 State:100
# Episode:83 Score:-9 State:[83]
# Episode:84 Score:-1008 State:120
# Episode:85 Score:-1022 State:[59]
# Episode:86 Score:-1011 State:120
# Episode:87 Score:-21 State:100
# Episode:88 Score:-23 State:[82]
# Episode:89 Score:-23 State:100
# Episode:90 Score:-19 State:[97]
# Episode:91 Score:-1011 State:120
# Episode:92 Score:-1012 State:120
# Episode:93 Score:-1012 State:[60]
# Episode:94 Score:-1018 State:120
# Episode:95 Score:-1013 State:120
# Episode:96 Score:-23 State:100
# Episode:97 Score:-1012 State:[78]
# Episode:98 Score:-17 State:100
# Episode:99 Score:-1022 State:[41]
# Episode:100 Score:-23 State:[100]

# %%
env.close()

# %%
#Save the model
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load('PPO_model', env=env)

# %%
#View logs in Tensorboard
training_log_path = os.path.join(log_path, 'PPO')
# !tensorboard --logdir={training_log_path}
