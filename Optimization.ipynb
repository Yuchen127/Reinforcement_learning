# %%
from gekko import GEKKO    
import numpy as np

# %%
m = GEKKO()
x = m.Array(m.Var,24,value=1,lb=0,ub=20)
x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24 = x
# change initial values
x2.value = -5; x3.value = 5 ; x4.value = 5; x5.value = 5
m.Equation(x1+x2+x3+x4+x5+x6+x7+x8+x9+x10+x11+x12+x13+x14+x15+x16+x17+x18+x19+x20+x21+x22+x23+x24==100)
m.Equation(x1+10>=0)
m.Equation(x1+10+x2>=0)
m.Minimize(x1*36.22+x2*27.98+x3*4.6+x4*9.38-x5*0.43+x6*2.26+x7*4.02+x8*8.48+x9*18.73+
           x10*20.64+x11*22.99+x12*18.93+x13*16.67+x14*9.51+x15*3.59+x16*2.31+
           x17*2.78+x18*6.3+x19*14.18+x20*16.11+x21*21.42+x22*25.87+x23*30.71+x24*18.44)
m.solve()
print('x: ', x)
print('profit: ',-1 * m.options.OBJFCNVAL)
# Out:
# apm 95.223.45.212_gk_model5 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.1
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :           26
#    Intermediates:            0
#    Connections  :            0
#    Equations    :            4
#    Residuals    :            4
#
#  Number of state variables:             26
#  Number of total equations: -            3
#  Number of slack variables: -            2
#  ---------------------------------------
#  Degrees of freedom       :             21
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ...

# %%
y = np.float32(np.array([36.22, 27.98, 4.6, 9.38, -0.43, 2.26, 4.02, 8.48, 18.73,
                                               20.64, 22.99, 18.93, 16.67, 9.51, 3.59, 2.31, 2.78, 6.3, 14.18,
                                               16.11, 21.42, 25.87, 30.71, 18.44]))

# %%
m = GEKKO()
x = m.Array(m.Var,24,value=1,lb=0,ub=100)
x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24 = x
# change initial values
x2.value = -5; x3.value = 5 ; x4.value = 5; x5.value = 5
m.Equation(x1+20>=0)
m.Equation(abs(x2-x1)<=20)
m.Equation(abs(x3-x2)<=20)
m.Equation(abs(x4-x3)<=20)
m.Equation(abs(x5-x4)<=20)
m.Equation(abs(x6-x5)<=20)
m.Equation(abs(x7-x6)<=20)
m.Equation(abs(x8-x7)<=20)
m.Equation(abs(x9-x8)<=20)
m.Equation(abs(x10-x9)<=20)
m.Equation(abs(x11-x10)<=20)
m.Equation(abs(x12-x11)<=20)
m.Equation(abs(x13-x12)<=20)
m.Equation(abs(x14-x13)<=20)
m.Equation(abs(x15-x14)<=20)
m.Equation(abs(x16-x15)<=20)
m.Equation(abs(x17-x16)<=20)
m.Equation(abs(x18-x17)<=20)
m.Equation(abs(x19-x18)<=20)
m.Equation(abs(x20-x19)<=20)
m.Equation(abs(x21-x20)<=20)
m.Equation(abs(x22-x21)<=20)
m.Equation(abs(x23-x22)<=20)
m.Equation(abs(x24-x23)<=20)
m.Equation(x24==100)
m.Minimize(x1*36.22+(x2-x1)*27.98+(x3-x2)*4.6+(x4-x3)*9.38-(x5-x4)*0.43+(x6-x5)*2.26+(x7-x6)*4.02+(x8-x7)*8.48+(x9-x8)*18.73+
           (x10-x9)*20.64+(x11-x10)*22.99+(x12-x11)*18.93+(x13-x12)*16.67+(x14-x13)*9.51+(x15-x14)*3.59+(x16-x15)*2.31+
           (x17-x16)*2.78+(x18-x17)*6.3+(x19-x18)*14.18+(x20-x19)*16.11+(x21-x20)*21.42+(x22-x21)*25.87+(x23-x22)*30.71+(x24-x23)*18.44)
m.solve()
print('x: ', x)
print('profit: ',-1 * m.options.OBJFCNVAL)
# Out:
# apm 95.223.45.212_gk_model6 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 1.0.1
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :           48
#    Intermediates:            0
#    Connections  :            0
#    Equations    :           26
#    Residuals    :           26
#
#  Number of state variables:             48
#  Number of total equations: -           25
#  Number of slack variables: -           24
#  ---------------------------------------
#  Degrees of freedom       :             -1
#
#  * Warning: DOF <= 0
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ...
